# %%
#Connect Google Colab with Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing necessery libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load The Data
Data = pd.read_excel("/content/drive/MyDrive/H.W2_Data mining/Online Retail.xlsx")
Data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#checking what are the variables here:
Data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#basic information about the dataset
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# #  Drop the rows without any invoice number (InvoiceNo)

# %%
print(Data.isnull().sum())
#Data['InvoiceNo'].isnull().sum()

#We noticed that there are no missing values ​​in this column
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# # Drop all transactions that were done on credit (cancelled). This is can be achieved by checking the letter 'c' in the InvoiceNo value

# %%
Letter = 'C'

filter = list((Data.InvoiceNo.str.contains(Letter))) 
 
for _ in range(filter.count(True)): 
    indx = filter.index(True) 
 
    Data.drop(indx, axis=0, inplace=True) 
 
    filter[indx] = " " 
#print(indx)

# %%
Data.shape
# Out:
# (532621, 8)

# %% [markdown]
# # Strip any extra spaces in the Description attribute

# %%
Data['Description'] = Data['Description'].str.strip()

# %%
Data['Description']
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905            CHILDREN'S APRON DOLLY GIRL
# 541906           CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908           BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 532621, dtype: object

# %% [markdown]
# # Print out on the screen the list of countries (Country) from which transactions had been done

# %%
print(Data['Country'].value_counts())
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# ...

# %% [markdown]
# # Using apriori algorithm, find out and generate all frequent itemsets in France. Don't print out all itemset. Just provide example(s) and explain one of them using the generated values (i.e. support, confidence, etc).

# %%
# Splitting the data according to the region of transaction
# Transactions done in France 
basket_France = (Data[Data['Country'] =="France"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))

# %%
# Defining the hot encoding function to make the data suitable  

def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# %%
# Applying one hot encoding 

basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded

# %%
basket_France.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
# Building the model 
frq_items = apriori(basket_France, min_support = 0.1, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

# %%
rules.head()
# Out:
#                                  antecedents                      consequents  \
# 40           (SET/6 RED SPOTTY PAPER PLATES)    (SET/6 RED SPOTTY PAPER CUPS)
# 43  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)    (SET/6 RED SPOTTY PAPER CUPS)
# 35       (STRAWBERRY LUNCH BOX WITH CUTLERY)                        (POSTAGE)
# 26      (ROUND SNACK BOXES SET OF4 WOODLAND)                        (POSTAGE)
# 41             (SET/6 RED SPOTTY PAPER CUPS)  (SET/6 RED SPOTTY PAPER PLATES)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 40            0.127551            0.137755  0.122449    0.960000  6.968889
# 43            0.107143            0.137755  0.102041    0.952381  6.913580
# 35            0.122449            0.765306  0.114796    0.937500  1.225000
# 26            0.158163            0.765306  0.147959    0.935484  1.222366
# 41            0.137755            0.127551  0.122449    0.888889  6.968889
#
#     leverage  conviction
# ...

# %% [markdown]
# # **Explanation of line 40**
#
# # - Antecedent support
# 0.127551
#
# Measures the importance of the antecedent or the proportion of transactions in the dataset is relatively low 12.76% (rare or abundance itemset).
#
# # - consequent support
# 0.137755
#
# Measures the importance of the consequent or the proportion of transactions in the dataset is relatively low 13.78% (rare or abundance itemset).
#
# # - support
# 0.122449
#
# Measures the overall importance or the proportion of transactions in the dataset is relatively low 12.2% (rare or abundance itemset).
#
# # - confidence
# 0.960000
#
# As the confidence is close to 1, the consequent and antecedent usually occur together.
# Note:
# Support can be beneficial for finding the connection between products in comparison to the whole dataset, whereas confidence looks at the connection between one or more items and another item.
#
# # - lift
# 6.968889
#
# The lift is > 1, (consequent and antecedent are statistically dependent), that lets us know the degree to which those two occurrences are dependent on one another, and makes those rules potentially useful for predicting the consequent in future data sets

# %%
#frequent itemsets in France
frq_items.head()
# Out:
#     support                     itemsets
# 0  0.102041  (ALARM CLOCK BAKELIKE PINK)
# 1  0.125000     (LUNCH BAG APPLE DESIGN)
# 2  0.153061    (LUNCH BAG RED RETROSPOT)
# 3  0.119898  (LUNCH BAG SPACEBOY DESIGN)
# 4  0.117347         (LUNCH BAG WOODLAND)
